# %% [markdown]
# <a href="https://colab.research.google.com/github/Jair-RM/Simulacion-I/blob/main/Ejercicio_24_04_23_(Aproximacion_a_la_Normal_Estandar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
num=10000
numeros=[]
while num!=0:
  u=random.random()
  x=(pow(u, 0.135) - pow(1-u, 0.135))/(0.1975)
  numeros.append(x)
  num-=1

media=np.mean(numeros)
varianza= np.var(numeros)


print("La media es ", media)

print("La varianza es ", varianza)

plt.hist(numeros, bins=50)
# Out:
# La media es  0.005586105092642182
# La varianza es  0.9768187175705256
# (array([  1.,   1.,   0.,   1.,   2.,   1.,   8.,  12.,  17.,  27.,  36.,
#          49.,  72.,  78., 117., 161., 187., 258., 276., 341., 375., 432.,
#         482., 505., 562., 564., 598., 575., 564., 577., 486., 478., 400.,
#         347., 296., 260., 208., 175., 138.,  79.,  72.,  54.,  46.,  37.,
#          25.,  11.,   6.,   2.,   0.,   1.]),
#  array([-3.88744103, -3.74159142, -3.59574181, -3.44989219, -3.30404258,
#         -3.15819297, -3.01234336, -2.86649375, -2.72064413, -2.57479452,
#         -2.42894491, -2.2830953 , -2.13724569, -1.99139608, -1.84554646,
#         -1.69969685, -1.55384724, -1.40799763, -1.26214802, -1.11629841,
#         -0.97044879, -0.82459918, -0.67874957, -0.53289996, -0.38705035,
#         -0.24120074, -0.09535112,  0.05049849,  0.1963481 ,  0.34219771,
#          0.48804732,  0.63389693,  0.77974655,  0.92559616,  1.07144577,
#          1.21729538,  1.36314499,  1.50899461,  1.65484422,  1.80069383,
#          1.94654344,  2.09239305,  2.23824266,  2.38409228,  2.52994189,
#          2.6757915 ,  2.82164111,  2.96749072,  3.11334033,  3.25918995,
#          3.40503956]),
#  <BarContainer object of 50 artists>)

# %%
plt.plot(numeros)

# %%
def cdf(numeros):
  n=len(numeros)
  x=np.sort(numeros)
  y=np.arange(0, len(numeros))/len(numeros)
  return x,y

X,Y=cdf(numeros)
plt.step(X,Y)
plt.step(X,Y)
plt.xlim(-5, 5)
plt.show()
