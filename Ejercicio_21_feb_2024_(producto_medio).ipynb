# %% [markdown]
# <a href="https://colab.research.google.com/github/Jair-RM/Simulacion-I/blob/main/Ejercicio_21_feb_2024_(producto_medio).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
p=int(input("Ecribe cuantos digitos quieresusar p= "))
x0=int(input("Ingrese el primer numero: "))
x=x0/(p*10)
# Verificar que realmente sean un numeros de p digitos
while x<1 and x>10:
  print("NO! tiene que ser un numero de", p, "digitos!")
  x0=int(input("Ingrese un numero: "))
  x=x0/(p*10)

x1=int(input("Ingrese el segundo numero: "))
x=x1/(p*10)
# Verificar que realmente sean un numeros de p digitos
while x<1 and x>10:
  print("NO! tiene que ser un numero de", p, "digitos!")
  x1=int(input("Ingrese un numero: "))
  x=x1/(p*10)

print("Se reemplazara el segundo numero")

numeros=[x0, x1]
print("Bien, tus numeros son:", numeros)

lista0=[x0]
lista1=[x1]

w=0
while w<10:
  x3=x0*x1
  print("Ahora, los multiplicamos: ", x0, "*", x1, " = ", x3)

  k=1
  s=x3/10
  while s>1:
   s=s/10
   k+=1
  print("EL numero", x3, "es de ", k, "digitos")

  m=k%2
  if m==1:
    n=k-p
    n=n/2
    s=str(x3)
    o=int(n)
    r=o+p
    nuevo=""
    l=1
    for i in s:
     if l<=r and l>o:
       nuevo+=i
     l+=1
    nue=int(nuevo)
    print("el nuevo numero es:", nue)
    num=nue
    numeros.append(num)

  if m==0:
   n=k-p
   o=int(n/2)
   s=str(x3)
   r=o+p
   nuevo=""
   l=1
   for i in s:
    if l<=r and l>o:
      nuevo+=i
    l+=1
   nue=int(nuevo)
   print("el nuevo numero es:", nue)
   num=nue
   numeros.append(num)

  x0=x1
  x1=num
  w+=1

  lista0.append(x0)
  lista1.append(x1)

print(lista0)
print(lista1)

print("Nuestros numeros creados son: \n  ", numeros)
# Out:
# Ecribe cuantos digitos quieresusar p= 3
# Ingrese el primer numero: 123
# Ingrese el segundo numero: 456
# Se reemplazara el segundo numero
# Bien, tus numeros son: [123, 456]
# Ahora, los multiplicamos:  123 * 456  =  56088
# EL numero 56088 es de  5 digitos
# el nuevo numero es: 608
# Ahora, los multiplicamos:  456 * 608  =  277248
# EL numero 277248 es de  6 digitos
# el nuevo numero es: 772
# Ahora, los multiplicamos:  608 * 772  =  469376
# EL numero 469376 es de  6 digitos
# el nuevo numero es: 693
# Ahora, los multiplicamos:  772 * 693  =  534996
# EL numero 534996 es de  6 digitos
# el nuevo numero es: 349
# Ahora, los multiplicamos:  693 * 349  =  241857
# EL numero 241857 es de  6 digitos
# el nuevo numero es: 418
# Ahora, los multiplicamos:  349 * 418  =  145882
# EL numero 145882 es de  6 digitos
# el nuevo numero es: 458
# Ahora, los multiplicamos:  418 * 458  =  191444
# EL numero 191444 es de  6 digitos
# el nuevo numero es: 914
# ...
